# %%
# docker-compose.yml

services:

  web:
    image: nginx
    ports:
      - "8080:80"

  database:
    image: mysql
    environment:
      MYSQL_ROOT_PASSWORD: root

# %%
# Run containers

docker compose up

# %%
# Stop containers

docker compose down
